# %%
import pymongo 
import credentials # load username and password from credentials.py
connection_string = f"mongodb+srv://{credentials.username}:{credentials.password}@cluster0.h4qnsp2.mongodb.net/?retryWrites=true&w=majority"

# %%
client = pymongo.MongoClient(connection_string)
db = client['cardio'] # this is a 'database'
collection = db['patients'] # this is a 'collection'

# %%
# to select all records in the document
for record in db.patients.find({}):
    print(record)
# Out:
# {'_id': 1, 'office_num': [5], 'patient_info': {'fname': 'Jack', 'lname': 'Smith', 'mname': 'Jane'}, 'patient_numbers': ['917-549-6721', '912-754-9170'], 'weights': [316, 196, 269, 105], 'height': 191, 'bp_readings': [{'Systolic': 111, 'Diastolic': 95, 'Rate': 110}, {'Systolic': 117, 'Diastolic': 86, 'Rate': 62}, {'Systolic': 112, 'Diastolic': 77, 'Rate': 107}, {'Systolic': 999, 'Diastolic': 999, 'Rate': 999}, {'Systolic': 999, 'Diastolic': 999, 'Rate': 999}], 'comments': 'good patient', 'readings': [{'Systolic': 999, 'Diastolic': 999, 'Rate': 999}]}
# ...

# %%
import json
query = { "_id": 1 } # search for any five start restaurants
doc = collection.find(query)
for record in doc:
  print(json.dumps(record, indent=4)) # using json.dumps() to make the output more readable
# Out:
# {
#     "_id": 1,
#     "office_num": [
#         5
#     ],
#     "patient_info": {
#         "fname": "Jack",
#         "lname": "Smith",
#         "mname": "Jane"
#     },
#     "patient_numbers": [
#         "917-549-6721",
#         "912-754-9170"
#     ],
#     "weights": [
#         316,
#         196,
#         269,
#         105
#     ],
#     "height": 191,
#     "bp_readings": [
#         {
#             "Systolic": 111,
#             "Diastolic": 95,
#             "Rate": 110
#         },
#         {
#             "Systolic": 117,
#             "Diastolic": 86,
#             "Rate": 62
#         },
#         {
#             "Systolic": 112,
#             "Diastolic": 77,
#             "Rate": 107
#         },
#         {
#             "Systolic": 999,
#             "Diastolic": 999,
#             "Rate": 999
#         },
#         {
#             "Systolic": 999,
#             "Diastolic": 999,
#             "Rate": 999
#         }
#     ],
# ...

# %%
query = { "comments": "good patient" }
doc = collection.find(query)
for record in doc:
  print(json.dumps(record, indent=4))
# Out:
# {
#     "_id": 1,
#     "office_num": [
#         5
#     ],
#     "patient_info": {
#         "fname": "Jack",
#         "lname": "Smith",
#         "mname": "Jane"
#     },
#     "patient_numbers": [
#         "917-549-6721",
#         "912-754-9170"
#     ],
#     "weights": [
#         316,
#         196,
#         269,
#         105
#     ],
#     "height": 191,
#     "bp_readings": [
#         {
#             "Systolic": 111,
#             "Diastolic": 95,
#             "Rate": 110
#         },
#         {
#             "Systolic": 117,
#             "Diastolic": 86,
#             "Rate": 62
#         },
#         {
#             "Systolic": 112,
#             "Diastolic": 77,
#             "Rate": 107
#         },
#         {
#             "Systolic": 999,
#             "Diastolic": 999,
#             "Rate": 999
#         },
#         {
#             "Systolic": 999,
#             "Diastolic": 999,
#             "Rate": 999
#         }
#     ],
# ...

# %%
query = { 'comments' : {'$regex' : 'ood'}} # https://en.wikipedia.org/wiki/Regular_expression
doc = collection.find(query)
for record in doc:
  print(json.dumps(record, indent=4))
# Out:
# {
#     "_id": 1,
#     "office_num": [
#         5
#     ],
#     "patient_info": {
#         "fname": "Jack",
#         "lname": "Smith",
#         "mname": "Jane"
#     },
#     "patient_numbers": [
#         "917-549-6721",
#         "912-754-9170"
#     ],
#     "weights": [
#         316,
#         196,
#         269,
#         105
#     ],
#     "height": 191,
#     "bp_readings": [
#         {
#             "Systolic": 111,
#             "Diastolic": 95,
#             "Rate": 110
#         },
#         {
#             "Systolic": 117,
#             "Diastolic": 86,
#             "Rate": 62
#         },
#         {
#             "Systolic": 112,
#             "Diastolic": 77,
#             "Rate": 107
#         },
#         {
#             "Systolic": 999,
#             "Diastolic": 999,
#             "Rate": 999
#         },
#         {
#             "Systolic": 999,
#             "Diastolic": 999,
#             "Rate": 999
#         }
#     ],
# ...

# %%
query = {'patient_numbers' : {'$regex' : '^721'}}
for patient in collection.find(query):
    print(patient)

# %%
# If you want to query on one field, you can use the following approach
query = { "bp_readings.Systolic" : 142} 
doc = collection.find(query)
for record in doc:
    print(json.dumps(record, indent=4))
# Out:
# {
#     "_id": 9,
#     "office_num": [
#         1
#     ],
#     "patient_info": {
#         "fname": "July",
#         "lname": "Langston"
#     },
#     "patient_numbers": [
#         "625-886-6248",
#         "554-242-8355",
#         "043-945-9498",
#         "251-887-8901"
#     ],
#     "weights": [
#         361,
#         110
#     ],
#     "height": 190,
#     "bp_readings": [
#         {
#             "Systolic": 101,
#             "Diastolic": 88,
#             "Rate": 99
#         },
#         {
#             "Systolic": 113,
#             "Diastolic": 93,
#             "Rate": 67
#         },
#         {
#             "Systolic": 111,
#             "Diastolic": 91,
#             "Rate": 89
#         },
#         {
#             "Systolic": 126,
#             "Diastolic": 75,
#             "Rate": 76
#         },
#         {
#             "Systolic": 149,
#             "Diastolic": 95,
#             "Rate": 87
#         },
#         {
#             "Systolic": 121,
# ...

# %%
# we can also check for greater than, greater than equal, less than, less than equal
query = { "bp_readings.Systolic" : {"$gte" : 130}} # in this style, you need all fields - so this one won't return anything
doc = collection.find(query)
for record in doc:
    print(json.dumps(record, indent=4))
# Out:
# {
#     "_id": 1,
#     "office_num": [
#         5
#     ],
#     "patient_info": {
#         "fname": "Jack",
#         "lname": "Smith",
#         "mname": "Jane"
#     },
#     "patient_numbers": [
#         "917-549-6721",
#         "912-754-9170"
#     ],
#     "weights": [
#         316,
#         196,
#         269,
#         105
#     ],
#     "height": 191,
#     "bp_readings": [
#         {
#             "Systolic": 111,
#             "Diastolic": 95,
#             "Rate": 110
#         },
#         {
#             "Systolic": 117,
#             "Diastolic": 86,
#             "Rate": 62
#         },
#         {
#             "Systolic": 112,
#             "Diastolic": 77,
#             "Rate": 107
#         },
#         {
#             "Systolic": 999,
#             "Diastolic": 999,
#             "Rate": 999
#         },
#         {
#             "Systolic": 999,
#             "Diastolic": 999,
#             "Rate": 999
#         }
#     ],
# ...

# %%
import bson

# %%
from bson import NumberInt
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# d:\big data\MongoDb\advances_queries_SC.ipynb Cell 11 line 1
# ----> <a href='vscode-notebook-cell:/d%3A/big%20data/MongoDb/advances_queries_SC.ipynb#X20sZmlsZQ%3D%3D?line=0'>1</a> from bson import NumberInt
#
# ImportError: cannot import name 'NumberInt' from 'bson' (c:\Users\csara\AppData\Local\Programs\Python\Python311\Lib\site-packages\bson\__init__.py)

# %%
query = { "bp_readings": {"Systolic" : 104 , "Diastolic": 82, "Rate": 81}} # in this style, you need all fields
doc = collection.find(query)
for record in doc:
  print(json.dumps(record, indent=4))

# %%
query = { "patient_numbers": {"$regex": '^707'}} # search for records that have this area code
doc = collection.find(query)
for record in doc:
  print(json.dumps(record, indent=4))

# %%
collection = db['persons']

# %%
db.persons.insert_many(
    [
  {
    "index": 0,
    "name": "Aurelia Gonzales",
    "isActive": False,
    "registered": "2015-02-11T04:22:39+0000",
    "age": 20,
    "gender": "female",
    "eyeColor": "green",
    "favoriteFruit": "banana",
    "company": {
      "title": "YURTURE",
      "email": "aureliagonzales@yurture.com",
      "phone": "+1 (940) 501-3963",
      "location": {
        "country": "USA",
        "address": "694 Hewes Street"
      }
    },
    "tags": [
      "enim",
      "id",
      "velit",
      "ad",
      "consequat"
    ]
  },
  {
    "index": 1,
    "name": "Kitty Snow",
    "isActive": False,
    "registered": "2018-01-23T04:46:15+0000",
    "age": 38,
    "gender": "female",
    "eyeColor": "blue",
    "favoriteFruit": "apple",
    "company": {
      "title": "DIGITALUS",
      "email": "kittysnow@digitalus.com",
      "phone": "+1 (949) 568-3470",
      "location": {
        "country": "Italy",
        "address": "154 Arlington Avenue"
      }
    },
    "tags": [
      "ut",
      "voluptate",
      "consequat",
      "consequat"
    ]
  },
  {
    "index": 2,
    "name": "Hays Wise",
    "isActive": False,
    "registered": "2018-01-23T04:46:15+0000",
    "age": 24,
    "gender": "male",
    "eyeColor": "green",
    "favoriteFruit": "strawberry",
    "company": {
      "title": "EXIAND",
      "email": "hayswise@exiand.com",
      "phone": "+1 (801) 583-3393",
      "location": {
        "country": "France",
        "address": "795 Borinquen Pl"
      }
    },
    "tags": [
      "amet",
      "ad",
      "elit",
      "ipsum"
    ]
  },
  {
    "index": 3,
    "name": "Karyn Rhodes",
    "isActive": True,
    "registered": "2018-01-23T04:46:15+0000",
    "age": 39,
    "gender": "female",
    "eyeColor": "green",
    "favoriteFruit": "strawberry",
    "company": {
      "title": "RODEMCO",
      "email": "karynrhodes@rodemco.com",
      "phone": "+1 (801) 505-3760",
      "location": {
        "country": "USA",
        "address": "521 Seigel Street"
      }
    },
    "tags": [
      "cillum",
      "exercitation",
      "excepteur"
    ]
  },
  {
    "index": 4,
    "name": "Alison Farmer",
    "isActive": False,
    "registered": "2018-01-23T04:46:15+0000",
    "age": 33,
    "gender": "female",
    "eyeColor": "brown",
    "favoriteFruit": "banana",
    "company": {
      "title": "OTHERSIDE",
      "email": "alisonfarmer@otherside.com",
      "phone": "+1 (902) 572-3954",
      "location": {
        "country": "Italy",
        "address": "356 Newkirk Placez"
      }
    },
    "tags": [
      "deserunt",
      "et",
      "duis",
      "dolor"
    ]
  },
  {
    "index": 5,
    "name": "Grace Larson",
    "isActive": True,
    "registered": "2018-01-23T04:46:15+0000",
    "age": 20,
    "gender": "female",
    "eyeColor": "blue",
    "favoriteFruit": "apple",
    "company": {
      "title": "OVOLO",
      "email": "gracelarson@ovolo.com",
      "phone": "+1 (930) 510-3310",
      "location": {
        "country": "USA",
        "address": "932 Linden Street"
      }
    },
    "tags": [
      "fugiat",
      "minim"
    ]
  },
  {
    "index": 6,
    "name": "Carmella Morse",
    "isActive": False,
    "registered": "2018-01-23T04:46:15+0000",
    "age": 39,
    "gender": "female",
    "eyeColor": "green",
    "favoriteFruit": "apple",
    "company": {
      "title": "SHEPARD",
      "email": "carmellamorse@shepard.com",
      "phone": "+1 (829) 478-3744",
      "location": {
        "country": "Germany",
        "address": "379 Tabor Court"
      }
    },
    "tags": [
      "amet",
      "cillum"
    ]
  },
  {
    "index": 7,
    "name": "Anastasia Blake",
    "isActive": True,
    "registered": "2018-01-23T04:46:15+0000",
    "age": 40,
    "gender": "female",
    "eyeColor": "brown",
    "favoriteFruit": "strawberry",
    "company": {
      "title": "ZERBINA",
      "email": "anastasiablake@zerbina.com",
      "phone": "+1 (867) 563-3788",
      "location": {
        "country": "Italy",
        "address": "147 Montague Terrace"
      }
    },
    "tags": [
      "Lorem",
      "consequat",
      "ex",
      "pariatur",
      "labore"
    ]
  },
  {
    "index": 8,
    "name": "Dale Holman",
    "isActive": False,
    "registered": "2018-01-23T04:46:15+0000",
    "age": 22,
    "gender": "male",
    "eyeColor": "green",
    "favoriteFruit": "strawberry",
    "company": {
      "title": "ISONUS",
      "email": "daleholman@isonus.com",
      "phone": "+1 (871) 452-3036",
      "location": {
        "country": "Italy",
        "address": "586 Blake Court"
      }
    },
    "tags": [
      "tempor",
      "aliqua",
      "duis"
    ]
  },
  {
    "index":9,
    "name": "Tina Barnett",
    "isActive": True,
    "registered": "2018-01-23T04:46:15+0000",
    "age": 39,
    "gender": "female",
    "eyeColor": "blue",
    "favoriteFruit": "apple",
    "company": {
      "title": "JETSILK",
      "email": "tinabarnett@jetsilk.com",
      "phone": "+1 (963) 569-3905",
      "location": {
        "country": "Germany",
        "address": "514 Lefferts Avenue"
      }
    },
    "tags": [
      "veniam",
      "proident"
    ]
  },
  {
    "index": 10,
    "name": "Belinda Zimmerman",
    "isActive": True,
    "registered": "2018-01-23T04:46:15+0000",
    "age": 34,
    "gender": "female",
    "eyeColor": "green",
    "favoriteFruit": "apple",
    "company": {
      "title": "COMTRAK",
      "email": "belindazimmerman@comtrak.com",
      "phone": "+1 (899) 410-3073",
      "location": {
        "country": "France",
        "address": "259 Bergen Street"
      }
    },
    "tags": [
      "nisi",
      "officia",
      "nisi"
    ]
  }
]
)

# %%
for person in db.persons.find({}):
    print(person)
# Out:
# {'_id': ObjectId('650e2af396bf966331cdabb0'), 'index': 0, 'name': 'Aurelia Gonzales', 'isActive': False, 'registered': '2015-02-11T04:22:39+0000', 'age': 20, 'gender': 'female', 'eyeColor': 'green', 'favoriteFruit': 'banana', 'company': {'title': 'YURTURE', 'email': 'aureliagonzales@yurture.com', 'phone': '+1 (940) 501-3963', 'location': {'country': 'USA', 'address': '694 Hewes Street'}}, 'tags': ['enim', 'id', 'velit', 'ad', 'consequat']}
# {'_id': ObjectId('650e2af396bf966331cdabb1'), 'index': 1, 'name': 'Kitty Snow', 'isActive': False, 'registered': '2018-01-23T04:46:15+0000', 'age': 38, 'gender': 'female', 'eyeColor': 'blue', 'favoriteFruit': 'apple', 'company': {'title': 'DIGITALUS', 'email': 'kittysnow@digitalus.com', 'phone': '+1 (949) 568-3470', 'location': {'country': 'Italy', 'address': '154 Arlington Avenue'}}, 'tags': ['ut', 'voluptate', 'consequat', 'consequat']}
# ...

# %%
averages = db.persons.aggregate([
    {'$match' : {'age' : {'$gt' : 38}}}
]
)
list(averages)
# Out:
# [{'_id': ObjectId('650e2af396bf966331cdabb3'),
#   'index': 3,
#   'name': 'Karyn Rhodes',
#   'isActive': True,
#   'registered': '2018-01-23T04:46:15+0000',
#   'age': 39,
#   'gender': 'female',
#   'eyeColor': 'green',
#   'favoriteFruit': 'strawberry',
#   'company': {'title': 'RODEMCO',
#    'email': 'karynrhodes@rodemco.com',
#    'phone': '+1 (801) 505-3760',
#    'location': {'country': 'USA', 'address': '521 Seigel Street'}},
#   'tags': ['cillum', 'exercitation', 'excepteur']},
#  {'_id': ObjectId('650e2af396bf966331cdabb6'),
#   'index': 6,
#   'name': 'Carmella Morse',
#   'isActive': False,
#   'registered': '2018-01-23T04:46:15+0000',
#   'age': 39,
#   'gender': 'female',
#   'eyeColor': 'green',
#   'favoriteFruit': 'apple',
#   'company': {'title': 'SHEPARD',
#    'email': 'carmellamorse@shepard.com',
#    'phone': '+1 (829) 478-3744',
#    'location': {'country': 'Germany', 'address': '379 Tabor Court'}},
#   'tags': ['amet', 'cillum']},
# ...

# %%
averages = db.persons.aggregate(
    [
        {'$match' : {'isActive' : True}}
    ]
)
list(averages)
# Out:
# [{'_id': ObjectId('650e2af396bf966331cdabb3'),
#   'index': 3,
#   'name': 'Karyn Rhodes',
#   'isActive': True,
#   'registered': '2018-01-23T04:46:15+0000',
#   'age': 39,
#   'gender': 'female',
#   'eyeColor': 'green',
#   'favoriteFruit': 'strawberry',
#   'company': {'title': 'RODEMCO',
#    'email': 'karynrhodes@rodemco.com',
#    'phone': '+1 (801) 505-3760',
#    'location': {'country': 'USA', 'address': '521 Seigel Street'}},
#   'tags': ['cillum', 'exercitation', 'excepteur']},
#  {'_id': ObjectId('650e2af396bf966331cdabb5'),
#   'index': 5,
#   'name': 'Grace Larson',
#   'isActive': True,
#   'registered': '2018-01-23T04:46:15+0000',
#   'age': 20,
#   'gender': 'female',
#   'eyeColor': 'blue',
#   'favoriteFruit': 'apple',
#   'company': {'title': 'OVOLO',
#    'email': 'gracelarson@ovolo.com',
#    'phone': '+1 (930) 510-3310',
#    'location': {'country': 'USA', 'address': '932 Linden Street'}},
#   'tags': ['fugiat', 'minim']},
# ...

# %%
averages = db.persons.aggregate([
    {'$group' : {'_id' : '$eyeColor'}}
])
list(averages)
# Out:
# [{'_id': 'green'}, {'_id': 'blue'}, {'_id': 'brown'}]

# %%
averages = db.patients.aggregate(
    [
        {'$match' : {'office_num' : {'$ne' : None}}},
        {'$group' : {'_id' : '$office_num', "average height" : {"$avg" : "$height"}}},
        {'$sort' : {'average height' : -1}}
    ]
)
list(averages)
# Out:
# [{'_id': [10], 'average height': 168.0},
#  {'_id': [2], 'average height': 162.5},
#  {'_id': [7], 'average height': 151.0},
#  {'_id': [5], 'average height': 147.57142857142858},
#  {'_id': [4], 'average height': 145.66666666666666},
#  {'_id': [1], 'average height': 136.77777777777777},
#  {'_id': [3], 'average height': 136.6},
#  {'_id': [6], 'average height': 136.2},
#  {'_id': [8], 'average height': 133.85714285714286},
#  {'_id': [9], 'average height': 117.33333333333333}]

# %%
import bson 

with open ('data/tweets.bson', 'rb') as fin:
    tweets = bson.decode_all(fin.read())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# d:\big data\MongoDb\advances_queries_SC.ipynb Cell 21 line 3
#       <a href='vscode-notebook-cell:/d%3A/big%20data/MongoDb/advances_queries_SC.ipynb#X33sZmlsZQ%3D%3D?line=0'>1</a> import bson
# ----> <a href='vscode-notebook-cell:/d%3A/big%20data/MongoDb/advances_queries_SC.ipynb#X33sZmlsZQ%3D%3D?line=2'>3</a> with open ('data/tweets.bson', 'rb') as fin:
#       <a href='vscode-notebook-cell:/d%3A/big%20data/MongoDb/advances_queries_SC.ipynb#X33sZmlsZQ%3D%3D?line=3'>4</a>     tweets = bson.decode_all(fin.read())
#
# File ~\AppData\Roaming\Python\Python311\site-packages\IPython\core\interactiveshell.py:282, in _modified_open(file, *args, **kwargs)
#     275 if file in {0, 1, 2}:
#     276     raise ValueError(
#     277         f"IPython won't let you open fd={file} by default "
# ...
